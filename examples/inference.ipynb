# %%
import dataclasses

import jax

from openpi.models import model as _model
from openpi.policies import droid_policy
from openpi.policies import policy_config as _policy_config
from openpi.shared import download
from openpi.training import config as _config
from openpi.training import data_loader as _data_loader

# %% [markdown]
# # Policy inference
#
# The following example shows how to create a policy from a checkpoint and run inference on a dummy example.

# %%
config = _config.get_config("pi0_fast_droid")
checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_fast_droid")

# Create a trained policy.
policy = _policy_config.create_trained_policy(config, checkpoint_dir)

# Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
example = droid_policy.make_droid_example()
result = policy.infer(example)

# Delete the policy to free up memory.
del policy

print("Actions shape:", result["actions"].shape)
# Out:
# Actions shape: (10, 8)

# %% [markdown]
# # Working with a live model
#
#
# The following example shows how to create a live model from a checkpoint and compute training loss. First, we are going to demonstrate how to do it with fake data.

# %%
config = _config.get_config("pi0_aloha_sim")

checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_aloha_sim")
key = jax.random.key(0)

# Create a model from the checkpoint.
model = config.model.load(_model.restore_params(checkpoint_dir / "params"))

# We can create fake observations and actions to test the model.
obs, act = config.model.fake_obs(), config.model.fake_act()

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)
print("Loss shape:", loss.shape)
# Out:
# Loss shape: (1, 50)

# %% [markdown]
# Now, we are going to create a data loader and use a real batch of training data to compute the loss.

# %%
# Reduce the batch size to reduce memory usage.
config = dataclasses.replace(config, batch_size=2)

# Load a single batch of data. This is the same data that will be used during training.
# NOTE: In order to make this example self-contained, we are skipping the normalization step
# since it requires the normalization statistics to be generated using `compute_norm_stats`.
loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
obs, act = next(iter(loader))

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)

# Delete the model to free up memory.
del model

print("Loss shape:", loss.shape)
# Out:
# Resolving data files:   0%|          | 0/50 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/root/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/.venv/lib/python3.11/site-packages/torch/__init__.py", line 24, in <module>
#     from typing import (
#   File "/work/.venv/lib/python3.11/site-packages/cv2/typing/__init__.py", line 61, in <module>
#     import cv2.mat_wrapper
# ImportError: libgthread-2.0.so.0: cannot open shared object file: No such file or directory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       4 # Load a single batch of data. This is the same data that will be used during training.
#       5 # NOTE: In order to make this example self-contained, we are skipping the normalization step
#       6 # since it requires the normalization statistics to be generated using `compute_norm_stats`.
#       7 loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
# ----> 8 obs, act = next(iter(loader))
#      10 # Sample actions from the model.
#      11 loss = model.compute_loss(key, obs, act)
#
# File /work/src/openpi/training/data_loader.py:539, in DataLoaderImpl.__iter__(self)
#     538 def __iter__(self):
# --> 539     for batch in self._data_loader:
#     540         yield _model.Observation.from_dict(batch), batch["actions"]
#
# File /work/src/openpi/training/data_loader.py:455, in TorchDataLoader.__iter__(self)
#     453 num_items = 0
#     454 while True:
# --> 455     data_iter = iter(self._data_loader)
#     456     while True:
#     457         if self._num_batches is not None and num_items >= self._num_batches:
#
# File /work/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:488, in DataLoader.__iter__(self)
#     486 if self.persistent_workers and self.num_workers > 0:
#     487     if self._iterator is None:
# --> 488         self._iterator = self._get_iterator()
#     489     else:
#     490         self._iterator._reset(self)
#
# File /work/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:424, in DataLoader._get_iterator(self)
#     422 else:
#     423     self.check_worker_number_rationality()
# --> 424     return _MultiProcessingDataLoaderIter(self)
#
# File /work/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1171, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1164 w.daemon = True
#    1165 # NB: Process.start() actually take some time as it needs to
#    1166 #     start a process and pass the arguments over via a pipe.
#    1167 #     Therefore, we only add a worker to self._workers list after
#    1168 #     it started, so that we do not call .join() if program dies
#    1169 #     before it starts, and __del__ tries to join but will get:
#    1170 #     AssertionError: can only join a started process.
# -> 1171 w.start()
#    1172 self._index_queues.append(index_queue)
#    1173 self._workers.append(w)
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/context.py:288, in SpawnProcess._Popen(process_obj)
#     285 @staticmethod
#     286 def _Popen(process_obj):
#     287     from .popen_spawn_posix import Popen
# --> 288     return Popen(process_obj)
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/popen_spawn_posix.py:32, in Popen.__init__(self, process_obj)
#      30 def __init__(self, process_obj):
#      31     self._fds = []
# ---> 32     super().__init__(process_obj)
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/multiprocessing/popen_spawn_posix.py:62, in Popen._launch(self, process_obj)
#      60     self.sentinel = parent_r
#      61     with open(parent_w, 'wb', closefd=False) as f:
# ---> 62         f.write(fp.getbuffer())
#      63 finally:
#      64     fds_to_close = []
#
# KeyboardInterrupt:
